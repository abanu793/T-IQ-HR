# %% [markdown]
# Resume CNN analysis, mainly for testing purpose

# %%
import pandas as pd

# Load predictions
pred_path = r"C:\Users\abanu\Documents\t_iq_hr\data\processed\resume_cnn_predictions.csv"
df = pd.read_csv(pred_path)

# Preview first 10 rows
df.head(10)

# Count predictions
print(df['prediction'].value_counts())
# Out:
# prediction
# real    4881
# Name: count, dtype: int64

# %%
import pandas as pd

# Correct path
csv_path = r"C:\Users\abanu\Documents\t_iq_hr\data\processed\resume_images\resume_images_labels.csv"

df = pd.read_csv(csv_path)

# Check labels
print(df['label'].value_counts())
# Out:
# label
# real    4881
# Name: count, dtype: int64

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\abanu\Documents\t_iq_hr\data\processed\resume_images\resume_images_labels.csv"
)

print(df["label"].value_counts())
# Out:
# label
# real    4881
# fake     600
# Name: count, dtype: int64

# %%
import pandas as pd

csv_path = r"C:\Users\abanu\Documents\t_iq_hr\data\processed\resume_images\resume_images_labels.csv"
df = pd.read_csv(csv_path)

print(df["label"].value_counts())
# Out:
# label
# real    4881
# Name: count, dtype: int64

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\abanu\Documents\t_iq_hr\data\processed\resume_images\resume_images_labels.csv")
print(df["label"].value_counts())
# Out:
# label
# real    4881
# fake      50
# Name: count, dtype: int64

# %%
df["label"].value_counts()
# Out:
# label
# real    4881
# fake      50
# Name: count, dtype: int64

# %%
import pandas as pd

csv_path = r"C:\Users\abanu\Documents\t_iq_hr\data\processed\resume_images\resume_images_labels.csv"
df = pd.read_csv(csv_path)

df["label"].value_counts()
# Out:
# label
# real    4881
# fake     600
# Name: count, dtype: int64
